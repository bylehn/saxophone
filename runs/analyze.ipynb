# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
def extract_data_from_npz(npz_path):
    # This function opens an npz file and extracts two pieces of information.
    # You need to replace 'key1' and 'key2' with the actual keys you're interested in.
    with np.load(npz_path) as data:
        info1 = data['poisson_target']
        info2 = data['poisson']
        info3 = data['forbidden_states_final']
    return info1, info2, info3

def find_and_extract_npz(root_path):
    # Initialize lists to store the extracted information
    info1_list = []
    info2_list = []
    info3_list = []
    
    for root, dirs, files in os.walk(root_path):
        for file in files:
            if file.endswith('.npz'):
                npz_path = os.path.join(root, file)
                info1, info2, info3 = extract_data_from_npz(npz_path)
                
                # Append the extracted information to the lists
                info1_list.append(info1)
                info2_list.append(info2)
                info3_list.append(info3)
                
    # At this point, info1_list and info2_list contain all the extracted information
    # You can return them, save them, or process them further as needed
    return info1_list, info2_list, info3_list

# Replace 'your/root/directory/path' with the path to the directory you want to start from
root_path = './'
info1_list, info2_list, info3_list = find_and_extract_npz(root_path)

# Concatenate the lists so each of the first entries becomes different columns
for info1, info2, info3 in zip(info1_list, info2_list, info3_list):
    print(f"{info1}, {info2}, {info3}")
# Out:
# 0.2, 0.11756905795629352, 4
# 0.2, 0.07869753220388624, 11
# 0.2, 0.08688040322728159, 7
# 0.2, 0.08214689930747443, 8
# 0.2, 0.14946252462759255, 1
# 0.3, 0.17423508742381505, 5
# 0.3, 0.11631230105572489, 13
# 0.3, 0.1011950768120621, 10
# 0.3, 0.12906076717557446, 9
# 0.3, 0.19478697962504993, 6
# -0.3, -0.18794334300543972, 3
# -0.3, -0.16995422147245684, 6
# -0.3, -0.13022760760937213, 8
# -0.3, -0.09785918773518967, 11
# -0.1, -0.03811551191090157, 6
# -0.1, -0.0573150091538483, 3
# -0.1, -0.04329058437238581, 6
# -0.1, -0.03518234772484959, 7
# -0.1, -0.029828319539289425, 3
# 0.4, 0.17117719343603444, 9
# 0.4, 0.14045155032332957, 14
# 0.4, 0.12225572342945307, 13
# 0.4, 0.20063986196852196, 9
# 0.4, 0.17431155650668098, 9
# 0.0, 0.00836765930532301, 5
# 0.0, 0.013453055284809766, 5
# 0.0, 0.005246517670265402, 6
# 0.0, 0.023479593372226916, 3
# -0.2, -0.130882788267967, 3
# -0.2, -0.11158436229423148, 5
# -0.2, -0.07766977359311149, 7
# -0.2, -0.0727528374486716, 6
# 0.5, 0.1870525770164349, 11
# 0.5, 0.1696939776152496, 13
# 0.5, 0.14755793694624483, 15
# 0.5, 0.24442061635122037, 13
# 0.5, 0.17566832257471693, 11
# 0.1, 0.06793745731389039, 4
# 0.1, 0.037265720276269364, 6
# 0.1, 0.05794782623432752, 5
# 0.1, 0.044205138311943906, 7
# 0.1, 0.08343905623273429, 3
# -0.4, -0.19780845320204837, 7
# -0.4, -0.16802821014147704, 4
# -0.4, -0.18466553892367782, 8
# -0.4, -0.16070267060837273, 7
# -0.4, -0.11225102987381058, 13
# -0.5, -0.14590369167153558, 11
# -0.5, -0.18036972420356437, 9
# -0.5, -0.15618185594089326, 13
# -0.5, -0.15567485745877166, 12
# -0.5, -0.15958332041981196, 10

# %%
# Prepare the figure and axes
fig, ax = plt.subplots()

# Plotting the second and third columns (info2_list and info3_list)
ax.scatter(info2_list, info3_list)

# Adding some plot decorations
ax.set_xlabel('Poisson ratio')
ax.set_ylabel('Difference in forbidden modes')
ax.legend()

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Prepare the figure and axes
fig, ax = plt.subplots()

# Plotting the second and third columns (info2_list and info3_list)
ax.scatter(info1_list, info2_list)

# Adding some plot decorations
ax.set_xlabel('Index')
ax.set_ylabel('Value')
ax.set_title('Line Plot of Info2 and Info3')
ax.legend()

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
